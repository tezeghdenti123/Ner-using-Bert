# %% [markdown]
# # NAMED ENTITY RECOGNITION:
#
# 1. The named entities are pre-defined categories chosen according to the use case such as names of people, organizations, places, codes, time notations, monetary values, etc.
#
# 1. NER aims to assign a class to each token (usually a single word) in a sequence. Because of this, NER is also referred to as token classification.

# %%
# !pip install simpletransformers
# Out:
# Requirement already satisfied: simpletransformers in /home/mohamedtez/.local/lib/python3.8/site-packages (0.65.1)
# Requirement already satisfied: seqeval in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: tensorboard in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (2.13.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from simpletransformers) (2.22.0)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (4.64.1)
# Requirement already satisfied: numpy in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (1.23.0)
# Requirement already satisfied: tensorboardx in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (2.6.2.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (2022.10.31)
# Requirement already satisfied: streamlit in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (1.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from simpletransformers) (1.5.0)
# Requirement already satisfied: scikit-learn in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (1.1.2)
# Requirement already satisfied: wandb>=0.10.32 in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (0.16.2)
# Requirement already satisfied: scipy in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (1.9.1)
# Requirement already satisfied: tokenizers in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (0.15.1)
# Requirement already satisfied: sentencepiece in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (0.1.99)
# Requirement already satisfied: transformers>=4.31.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (4.37.2)
# Requirement already satisfied: datasets in /home/mohamedtez/.local/lib/python3.8/site-packages (from simpletransformers) (2.16.1)
# Requirement already satisfied: protobuf>=3.19.6 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (4.25.2)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard->simpletransformers) (0.34.2)
# Requirement already satisfied: grpcio>=1.48.2 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.50.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (2.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard->simpletransformers) (45.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (2.14.1)
# Requirement already satisfied: absl-py>=0.4 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.3.0)
# Requirement already satisfied: packaging in /home/mohamedtez/.local/lib/python3.8/site-packages (from tensorboardx->simpletransformers) (23.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (1.6.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (3.1.41)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.8.1b0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (8.2.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (13.7.0)
# Requirement already satisfied: watchdog>=2.1.5; platform_system != "Darwin" in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (6.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (4.4.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: altair<6,>=4.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.2.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (6.2)
# Requirement already satisfied: validators<1,>=0.2 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.22.0)
# Requirement already satisfied: pyarrow>=7.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (15.0.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.2)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (2.8.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (10.2.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.2.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->simpletransformers) (8.1.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->simpletransformers) (2022.2.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from scikit-learn->simpletransformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from scikit-learn->simpletransformers) (3.1.0)
# Requirement already satisfied: setproctitle in /home/mohamedtez/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (1.3.3)
# Requirement already satisfied: PyYAML in /usr/lib/python3/dist-packages (from wandb>=0.10.32->simpletransformers) (5.3.1)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (1.40.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/mohamedtez/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: psutil>=5.0.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (5.9.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/mohamedtez/.local/lib/python3.8/site-packages (from tokenizers->simpletransformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from transformers>=4.31.0->simpletransformers) (0.4.2)
# Requirement already satisfied: filelock in /home/mohamedtez/.local/lib/python3.8/site-packages (from transformers>=4.31.0->simpletransformers) (3.9.0)
# Requirement already satisfied: aiohttp in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (3.9.3)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (2023.10.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (0.3.7)
# Requirement already satisfied: multiprocess in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (0.70.16)
# Requirement already satisfied: pyarrow-hotfix in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (0.6)
# Requirement already satisfied: xxhash in /home/mohamedtez/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (3.4.1)
# Requirement already satisfied: six>=1.5.2 in /home/mohamedtez/.local/lib/python3.8/site-packages (from grpcio>=1.48.2->tensorboard->simpletransformers) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/mohamedtez/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->simpletransformers) (4.0.11)
# Requirement already satisfied: jinja2>=2.10.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from pydeck<1,>=0.8.0b4->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/mohamedtez/.local/lib/python3.8/site-packages (from importlib-metadata<8,>=1.4->streamlit->simpletransformers) (3.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.16.0)
# Requirement already satisfied: toolz in /home/mohamedtez/.local/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.12.1)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /home/mohamedtez/.local/lib/python3.8/site-packages (from tzlocal<6,>=1.1->streamlit->simpletransformers) (0.2.1)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk>=1.0.0->wandb>=0.10.32->simpletransformers) (2019.11.28)
# Requirement already satisfied: urllib3>=1.26.11; python_version >= "3.6" in /home/mohamedtez/.local/lib/python3.8/site-packages (from sentry-sdk>=1.0.0->wandb>=0.10.32->simpletransformers) (2.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (22.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mohamedtez/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (6.0.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/mohamedtez/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.8)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->simpletransformers) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /home/mohamedtez/.local/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/mohamedtez/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (5.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/mohamedtez/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.18.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /home/mohamedtez/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (1.3.10)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->datasets->simpletransformers) (2.8)

# %%
import pandas as pd
data = pd.read_csv("ner_dataset.csv",encoding="latin1" )

# %%
data.head(30)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1           NaN             of   IN      O
# 2           NaN  demonstrators  NNS      O
# 3           NaN           have  VBP      O
# 4           NaN        marched  VBN      O
# 5           NaN        through   IN      O
# 6           NaN         London  NNP  B-geo
# 7           NaN             to   TO      O
# 8           NaN        protest   VB      O
# 9           NaN            the   DT      O
# 10          NaN            war   NN      O
# 11          NaN             in   IN      O
# 12          NaN           Iraq  NNP  B-geo
# 13          NaN            and   CC      O
# 14          NaN         demand   VB      O
# 15          NaN            the   DT      O
# 16          NaN     withdrawal   NN      O
# 17          NaN             of   IN      O
# 18          NaN        British   JJ  B-gpe
# 19          NaN         troops  NNS      O
# 20          NaN           from   IN      O
# 21          NaN           that   DT      O
# 22          NaN        country   NN      O
# 23          NaN              .    .      O
# 24  Sentence: 2       Families  NNS      O
# 25          NaN             of   IN      O
# 26          NaN       soldiers  NNS      O
# 27          NaN         killed  VBN      O
# 28          NaN             in   IN      O
# 29          NaN            the   DT      O

# %%
data =data.fillna(method ="ffill")

# %%
data.head(30)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O
# 20  Sentence: 1           from   IN      O
# 21  Sentence: 1           that   DT      O
# 22  Sentence: 1        country   NN      O
# 23  Sentence: 1              .    .      O
# 24  Sentence: 2       Families  NNS      O
# 25  Sentence: 2             of   IN      O
# 26  Sentence: 2       soldiers  NNS      O
# 27  Sentence: 2         killed  VBN      O
# 28  Sentence: 2             in   IN      O
# 29  Sentence: 2            the   DT      O

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data["Sentence #"] = LabelEncoder().fit_transform(data["Sentence #"] )

# %%
data.head(30)
# Out:
#     Sentence #           Word  POS    Tag
# 0            0      Thousands  NNS      O
# 1            0             of   IN      O
# 2            0  demonstrators  NNS      O
# 3            0           have  VBP      O
# 4            0        marched  VBN      O
# 5            0        through   IN      O
# 6            0         London  NNP  B-geo
# 7            0             to   TO      O
# 8            0        protest   VB      O
# 9            0            the   DT      O
# 10           0            war   NN      O
# 11           0             in   IN      O
# 12           0           Iraq  NNP  B-geo
# 13           0            and   CC      O
# 14           0         demand   VB      O
# 15           0            the   DT      O
# 16           0     withdrawal   NN      O
# 17           0             of   IN      O
# 18           0        British   JJ  B-gpe
# 19           0         troops  NNS      O
# 20           0           from   IN      O
# 21           0           that   DT      O
# 22           0        country   NN      O
# 23           0              .    .      O
# 24       11111       Families  NNS      O
# 25       11111             of   IN      O
# 26       11111       soldiers  NNS      O
# 27       11111         killed  VBN      O
# 28       11111             in   IN      O
# 29       11111            the   DT      O

# %%
data.rename(columns={"Sentence #":"sentence_id","Word":"words","Tag":"labels"}, inplace =True)

# %%
data["labels"] = data["labels"].str.upper()

# %%
X= data[["sentence_id","words"]]
Y =data["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["words"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["words"],"labels":y_test})

# %%
train_data
# Out:
#         sentence_id       words labels
# 979802        38673     entered      O
# 757591        27365     portion      O
# 537788        16231  terrorists      O
# 624549        20609         the      O
# 220163           92         his      O
# ...             ...         ...    ...
# 439641        11205       after      O
# 928204        36003       China  B-GEO
# 731602        26051      Kirkuk  B-GEO
# 628020        20783          on      O
# 995602        39473      Police      O
#
# [838860 rows x 3 columns]

# %% [markdown]
# # Model Training

# %%
from simpletransformers.ner import NERModel,NERArgs
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.2.0) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# 2024-02-03 17:44:30.224454: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-03 17:44:30.458839: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-03 17:44:31.330612: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
label = data["labels"].unique().tolist()
label
# Out:
# ['O',
#  'B-GEO',
#  'B-GPE',
#  'B-PER',
#  'I-GEO',
#  'B-ORG',
#  'I-ORG',
#  'B-TIM',
#  'B-ART',
#  'I-ART',
#  'I-PER',
#  'I-GPE',
#  'I-TIM',
#  'B-NAT',
#  'B-EVE',
#  'I-EVE',
#  'I-NAT']

# %%
args = NERArgs()
args.num_train_epochs = 1
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model = NERModel('bert', 'bert-base-cased',labels=label,args =args,use_cuda = False )
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# /home/mohamedtez/.local/lib/python3.8/site-packages/simpletransformers/ner/ner_utils.py:190: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   return [
#   0%|          | 0/13 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Running Epoch 1 of 1:   0%|          | 0/1499 [00:00<?, ?it/s]

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46695.0), HTML(value='')))
# HBox(children=(HTML(value='Running Evaluation'), FloatProgress(value=0.0, max=1460.0), HTML(value='')))

# %%
result
# Out:
# {'eval_loss': 0.17127630058676005,
#  'f1_score': 0.7936661066848524,
#  'precision': 0.8275694613063235,
#  'recall': 0.7624312923430909}

# %%
prediction, model_output = model.predict(["What is the new name of Bangalore"])
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Running Prediction'), FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %%
prediction
# Out:
# [[{'What': 'O'},
#   {'is': 'O'},
#   {'the': 'O'},
#   {'new': 'O'},
#   {'name': 'O'},
#   {'of': 'O'},
#   {'Bangalore': 'B-GEO'}]]
